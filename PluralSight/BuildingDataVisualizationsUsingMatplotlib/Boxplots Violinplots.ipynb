# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
x = np.random.randint(low=0, high=20, size=20)
x.sort()
x
# Out:
# array([ 0,  0,  1,  3,  6,  7,  8, 10, 10, 11, 11, 12, 13, 14, 14, 14, 15,
#        15, 16, 18])

# %%
plt.boxplot(x)
plt.show()

# %%
x = np.append(x, 22)

plt.boxplot(x)
plt.show()

# %%
x = np.append(x, 37)
x = np.append(x, 40)

plt.boxplot(x)
plt.show()

# %%
plt.boxplot(x, vert=False, notch=True)
plt.show()

# %%
plt.boxplot(x, vert=False, notch=True, showfliers=False)
plt.show()

# %%
bp = plt.boxplot(x, patch_artist=True)
bp
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12d4d9640>,
#   <matplotlib.lines.Line2D at 0x12d4d99a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x12d4d9d00>,
#   <matplotlib.lines.Line2D at 0x12d4e40a0>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x12d4d92e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x12d4e4400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12d4e4760>],
#  'means': []}

# %%
print("Number of boxes:", len(bp["boxes"]))
print("Number of whiskers:", len(bp["whiskers"]))
print("Number of caps:", len(bp["caps"]))
print("Number of medians:", len(bp["medians"]))
print("Number of fliers:", len(bp["fliers"]))
# Out:
# Number of boxes: 1
# Number of whiskers: 2
# Number of caps: 2
# Number of medians: 1
# Number of fliers: 1

# %%
bp = plt.boxplot(x, patch_artist=True)
bp["boxes"][0].set(facecolor="lightyellow",
                  edgecolor="maroon",
                  hatch=".")
# Out:
# [None, None, None]

# %%
bp = plt.boxplot(x, patch_artist=True)
bp["boxes"][0].set(facecolor="lightyellow",
                  edgecolor="maroon",
                  hatch=".")

bp["whiskers"][0].set(color="red", linewidth=2)
bp["whiskers"][1].set(color="blue")
# Out:
# [None]

# %%
bp = plt.boxplot(x, patch_artist=True)
bp["boxes"][0].set(facecolor="lightyellow",
                  edgecolor="maroon",
                  hatch="/")
bp["fliers"][0].set(marker="D", markerfacecolor="blue")
# Out:
# [None, None]

# %%
bp = plt.boxplot(x, patch_artist=True)
bp["boxes"][0].set(facecolor="lightyellow",
                  edgecolor="maroon")
bp["medians"][0].set(linestyle="--", linewidth=3)
# Out:
# [None, None]

# %%
import pandas as pd

# %%
exam_data = pd.read_csv("./files/exams.csv")

# %%
exam_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C            some high school  free/reduced
# 1  female        group C                some college  free/reduced
# 2    male        group A                 high school      standard
# 3    male        group B                some college      standard
# 4  female        group C             master's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          69             61             58
# 1               completed          47             65             69
# 2                    none          66             52             53
# 3                    none          88             89             82
# 4                    none          62             82             76

# %%
exam_scores = exam_data[["math score", "reading score", "writing score"]]
exam_scores.head()
# Out:
#    math score  reading score  writing score
# 0          69             61             58
# 1          47             65             69
# 2          66             52             53
# 3          88             89             82
# 4          62             82             76

# %%
exam_scores.describe()
# Out:
#        math score  reading score  writing score
# count  100.000000     100.000000     100.000000
# mean    67.150000      69.180000      67.780000
# std     12.797865      13.832607      14.874954
# min     36.000000      34.000000      33.000000
# 25%     56.000000      60.000000      57.750000
# 50%     68.000000      69.000000      68.500000
# 75%     76.000000      80.000000      77.250000
# max     95.000000      99.000000     100.000000

# %%
exam_scores_array = np.array(exam_scores)
exam_scores_array
# Out:
# array([[ 69,  61,  58],
#        [ 47,  65,  69],
#        [ 66,  52,  53],
#        [ 88,  89,  82],
#        [ 62,  82,  76],
#        [ 47,  69,  60],
#        [ 71,  66,  74],
#        [ 57,  62,  60],
#        [ 60,  67,  65],
#        [ 74,  72,  76],
#        [ 77,  71,  67],
#        [ 69,  79,  83],
#        [ 65,  62,  56],
#        [ 55,  58,  51],
#        [ 78,  88,  91],
#        [ 70,  72,  72],
#        [ 55,  69,  55],
#        [ 68,  68,  62],
#        [ 73,  62,  58],
#        [ 54,  50,  51],
#        [ 81,  76,  77],
#        [ 70,  76,  73],
#        [ 64,  62,  63],
#        [ 51,  66,  63],
#        [ 49,  50,  43],
#        [ 83,  80,  82],
#        [ 86,  92,  81],
#        [ 83,  89,  94],
#        [ 61,  77,  68],
#        [ 55,  50,  44],
#        [ 56,  59,  55],
#        [ 46,  57,  61],
#        [ 68,  60,  52],
#        [ 78,  75,  69],
#        [ 85,  94,  93],
#        [ 95,  99,  95],
#        [ 82,  74,  78],
#        [ 94,  85,  96],
#        [ 64,  71,  68],
#        [ 70,  80,  85],
#        [ 84,  78,  84],
#        [ 62,  81,  73],
#        [ 52,  58,  53],
#        [ 89,  72,  74],
#        [ 64,  63,  63],
#        [ 74,  77,  72],
#        [ 50,  54,  54],
#        [ 86,  76,  82],
#        [ 53,  62,  64],
#        [ 36,  35,  33],
#        [ 64,  81,  75],
#        [ 71,  69,  74],
#        [ 73,  79,  77],
#        [ 80,  81,  72],
#        [ 75,  66,  67],
#        [ 64,  57,  51],
#        [ 68,  87,  77],
#        [ 73,  60,  65],
#        [ 77,  76,  69],
#        [ 85,  89,  85],
#        [ 77,  85,  82],
#        [ 53,  70,  72],
#        [ 48,  43,  42],
#        [ 91,  91, 100],
#        [ 67,  81,  85],
#        [ 74,  87,  88],
#        [ 70,  82,  78],
#        [ 65,  56,  58],
#        [ 75,  67,  63],
#        [ 63,  56,  49],
#        [ 86,  92,  94],
#        [ 76,  87,  85],
#        [ 56,  62,  67],
#        [ 48,  61,  64],
#        [ 67,  62,  60],
#        [ 80,  86,  88],
#        [ 77,  73,  74],
#        [ 51,  58,  53],
#        [ 71,  80,  84],
#        [ 59,  67,  72],
#        [ 69,  62,  57],
#        [ 74,  71,  71],
#        [ 63,  68,  65],
#        [ 68,  54,  50],
#        [ 69,  79,  73],
#        [ 75,  86,  89],
#        [ 79,  81,  74],
#        [ 51,  36,  44],
#        [ 59,  60,  56],
#        [ 49,  55,  49],
#        [ 76,  76,  69],
#        [ 75,  78,  77],
#        [ 54,  45,  43],
#        [ 45,  63,  65],
#        [ 75,  75,  78],
#        [ 56,  59,  61],
#        [ 64,  57,  62],
#        [ 62,  48,  38],
#        [ 44,  34,  36],
#        [ 48,  48,  40]])

# %%
bp = plt.boxplot(exam_scores_array)
plt.show()

# %%
bp = plt.boxplot(exam_scores_array, patch_artist=True)
plt.show()

# %%
print("Number of boxes:", len(bp["boxes"]))
print("Number of whiskers:", len(bp["whiskers"]))
print("Number of caps:", len(bp["caps"]))
print("Number of medians:", len(bp["medians"]))
print("Number of fliers:", len(bp["fliers"]))
# Out:
# Number of boxes: 3
# Number of whiskers: 6
# Number of caps: 6
# Number of medians: 3
# Number of fliers: 3

# %%
colors = ["blue", "grey", "lawngreen"]

# %%
bp = plt.boxplot(exam_scores_array, patch_artist=True)
for i in range(len(bp["boxes"])):
    bp["boxes"][i].set(facecolor=colors[i])
    bp["caps"][2*i + 1].set(color=colors[i])
plt.xticks([1,2,3], ["Math", "Reading", "Writing"])
# Out:
# ([<matplotlib.axis.XTick at 0x12d6a2be0>,
#   <matplotlib.axis.XTick at 0x12d6a2250>,
#   <matplotlib.axis.XTick at 0x12d65ca30>],
#  [Text(1, 0, 'Math'), Text(2, 0, 'Reading'), Text(3, 0, 'Writing')])

# %%
vp = plt.violinplot(exam_scores_array)
plt.show()

# %%
vp = plt.violinplot(exam_scores_array, showmedians=True)
plt.xticks([1,2,3], ["Math", "Reading", "Writing"])
plt.show()

# %%
vp = plt.violinplot(exam_scores_array, showmedians=True, vert=False)
plt.yticks([1,2,3], ["Math", "Reading", "Writing"])
plt.show()

# %%
vp
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1311a82b0>,
#   <matplotlib.collections.PolyCollection at 0x1311a85b0>,
#   <matplotlib.collections.PolyCollection at 0x1311a8790>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x114d92ca0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1311a8c70>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1311a8fd0>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x1311b8370>}

# %%
vp = plt.violinplot(exam_scores_array, showmedians=True, vert=False)
plt.yticks([1,2,3], ["Math", "Reading", "Writing"])

for i in range(len(vp["bodies"])):
    vp["bodies"][i].set(facecolor=colors[i])

plt.show()

# %%
vp = plt.violinplot(exam_scores_array, showmedians=True, vert=False)
plt.yticks([1,2,3], ["Math", "Reading", "Writing"])

for i in range(len(vp["bodies"])):
    vp["bodies"][i].set(facecolor=colors[i])

vp["cmaxes"].set(color="maroon")
vp["cmins"].set(color="black")
vp["cbars"].set(linestyle=":")
vp["cmedians"].set(linewidth=6)
    
plt.show()

# %%
vp = plt.violinplot(exam_scores_array, showmedians=True, vert=False)
plt.yticks([1,2,3], ["Math", "Reading", "Writing"])

for i in range(len(vp["bodies"])):
    vp["bodies"][i].set(facecolor=colors[i])

plt.legend(handles = [vp["bodies"][0], vp["bodies"][1]],
           labels=["Math", "Reading"],
           loc="upper left")
    
plt.show()
