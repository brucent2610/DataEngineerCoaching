# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
data = pd.read_csv("./files/sector_weighting.csv")
data.head()
# Out:
#               Sector  Percentage
# 0  General Financial          20
# 1          Beverages          35
# 2     Life Insurance          25
# 3            Tobacco           5
# 4             Travel          15

# %%
plt.pie(data["Percentage"], labels=data["Sector"])
plt.axis("equal")
plt.show()

# %%
colors = ["deeppink", "aqua", "magenta", "silver", "lime"]

# %%
plt.pie(data["Percentage"], labels=data["Sector"],
       colors=colors,
       autopct="%.2f")
plt.axis("equal")
plt.show()

# %%
plt.pie(data["Percentage"], labels=data["Sector"],
       colors=colors,
       autopct="%.2f",
       startangle=90,
       counterclock=False)
plt.axis("equal")
plt.show()

# %%
explode = (0, 0.1, 0, 0.3, 0)

# %%
plt.pie(data["Percentage"], labels=data["Sector"],
       colors=colors,
       autopct="%.2f",
       explode=explode)
plt.axis("equal")
plt.show()

# %%
wedges, texts, autotexts = plt.pie(data["Percentage"], labels=data["Sector"],
       colors=colors,
       autopct="%.2f",
       explode=explode)
plt.axis("equal")

print("Wedges", wedges)
print("Texts", texts)
print("Autotexts", autotexts)
# Out:
# Wedges [<matplotlib.patches.Wedge object at 0x12ee83be0>, <matplotlib.patches.Wedge object at 0x12eea52b0>, <matplotlib.patches.Wedge object at 0x12eea5940>, <matplotlib.patches.Wedge object at 0x12eea5f70>, <matplotlib.patches.Wedge object at 0x12eec7640>]
# Texts [Text(0.8899186877588753, 0.6465637858537406, 'General Financial'), Text(-0.848528137423857, 0.8485281374238571, 'Beverages'), Text(-0.49938956806635254, -0.9801071672559599, 'Life Insurance'), Text(0.6355866791969632, -1.2474091442776012, 'Tobacco'), Text(0.9801071789450159, -0.49938954512528877, 'Travel')]
# Autotexts [Text(0.4854101933230228, 0.35267115592022213, '20.00'), Text(-0.4949747468305832, 0.4949747468305833, '35.00'), Text(-0.2723943098543741, -0.5346039094123417, '25.00'), Text(0.4085914366266191, -0.801905878464172, '5.00'), Text(0.5346039157881904, -0.27239429734106657, '15.00')]

# %%
wedges, texts, autotexts = plt.pie(data["Percentage"], labels=data["Sector"],
       colors=colors,
       autopct="%.2f",
       explode=explode)
plt.axis("equal")

wedges[1].set(edgecolor="red", linewidth=2)
texts[1].set(family="cursive", size=20)
autotexts[1].set(weight="bold", size=15)
